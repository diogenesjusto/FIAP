# %% [markdown]
# <a href="https://colab.research.google.com/github/diogenesjusto/FIAP/blob/master/Gradua%C3%A7%C3%A3o/2026/2TSCPV_20260924_P1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/diogenesjusto/FIAP/refs/heads/master/Gradua%C3%A7%C3%A3o/dados/dados_arvore_titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.crosstab(df['Survived'], df['Sex'], margins=True)
# Out:
# Sex       female  male  All
# Survived
# 0             81   468  549
# 1            233   109  342
# All          314   577  891

# %%
# Probabilidade de sobrevivência de um passageiro embarcado no titanic
# P = x/T
P_sobrevivencia = 342/891
P_sobrevivencia
# Out:
# 0.3838383838383838

# %%
# Pela 2.a Axioma de probabilidades, calculamos a P_morte
P_morte = 1 - P_sobrevivencia
P_morte
# Out:
# 0.6161616161616161

# %%
# Probabilidade de um passageiro ser do gênero feminino
P_mulher = 314/891
P_mulher
# Out:
# 0.35241301907968575

# %%
# Probabilidades de sobrevivência de mulheres e homens => P(A|B) = P(A U B)/PB
P_sob_mulher = 233/314
P_sob_mulher
# Out:
# 0.7420382165605095

# %%
P_sob_homens = 109/577
P_sob_homens
# Out:
# 0.18890814558058924

# %%
# Se fizermos com classe (Pclass), ao invés de gênero (Sex)
pd.crosstab(df['Survived'], df['Pclass'], margins=True)
# Out:
# Pclass      1    2    3  All
# Survived
# 0          80   97  372  549
# 1         136   87  119  342
# All       216  184  491  891
