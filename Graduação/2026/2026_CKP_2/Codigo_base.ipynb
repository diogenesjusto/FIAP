# %% [markdown]
# <a href="https://colab.research.google.com/github/diogenesjusto/FIAP/blob/master/Gradua%C3%A7%C3%A3o/2026/2026_CKP_2/Codigo_base.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from google.colab import files
df = pd.read_csv("https://raw.githubusercontent.com/diogenesjusto/FIAP/refs/heads/master/Gradua%C3%A7%C3%A3o/2026/2026_CKP_2/dados_bb.csv", )

treino = df.iloc[0:365,]
teste = df.iloc[366:396,]

y_treino = treino['venda']
x_treino = treino[['outmg']]
x_teste = teste[['outmg']]

mod = LinearRegression()
mod.fit(x_treino, y_treino)
prev = mod.predict(x_teste) # Substitui teste['desconto'] pelo resultado do predict

pd.DataFrame(prev).to_csv('predict.csv')
files.download('predict.csv')
