# %%
# Pycaret
# 1. Install
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 483.9/483.9 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 32.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 16.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 22.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 12.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 86.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 30.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

# 2. Importar bibliotecas - neste caso, classificadores
from pycaret.classification import *

# %%
df = pd.read_csv('https://raw.githubusercontent.com/diogenesjusto/FIAP/master/Gradua%C3%A7%C3%A3o/dados/dados_arvore_titanic.csv')

# %%
# 3. Setup da função de classificação
s = setup(df, target='Survived')
# Out:
# <style type="text/css">
# #T_8e43c_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_8e43c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8e43c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_8e43c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e43c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8e43c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_8e43c_row0_col1" class="data row0 col1" >3935</td>
#     </tr>
#     <tr>
#       <th id="T_8e43c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8e43c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_8e43c_row1_col1" class="data row1 col1" >Survived</td>
#     </tr>
#     <tr>
#       <th id="T_8e43c_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# 4. Comparação de modelos
best = compare_models()
# Out:
# <style type="text/css">
# #T_d5c38 th {
#   text-align: left;
# }
# ...

# %%
# 4. Visualização do melhor modelo
print(best)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=3935, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# 5. Avaliação do modelo
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
