# %% [markdown]
# <a href="https://colab.research.google.com/github/diogenesjusto/FIAP/blob/master/Gradua%C3%A7%C3%A3o/2023/20230307_Exercicio_De_Regressao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Carga de bibliotecas e base de dados
import pandas as pd
from sklearn.linear_model import LinearRegression

df = pd.read_csv("https://raw.githubusercontent.com/diogenesjusto/FIAP/master/Gradua%C3%A7%C3%A3o/dados/pib.csv")

# %%
# 2. Análise Exploratória
df.head()
# Out:
#      Unnamed: 0 ANO_MES     PIB     BRL     BRP     BRT     SLP     SPP  \
# 133         134  fev/15  144.42  147.35  133.73  143.57  147.81  148.96
# 134         135  mar/15  151.68  149.64  163.27  152.09  154.87  179.07
# 135         136  abr/15  147.03  153.81  149.93  152.28  161.21  164.74
# 136         137  mai/15  148.94  149.66  153.03  149.82  157.03  169.39
# 137         138  jun/15  147.37  146.13  147.98  145.84  152.96  162.92
#
#         SPT     PRL  ...   PIBi3   PIBi4   PIBi5   PIBi6   PIBi7   PIBi8  \
# 133  147.54  157.30  ...  151.46  156.65  154.04  154.75  154.34  148.92
# 134  159.56  147.28  ...  150.70  151.46  156.65  154.04  154.75  154.34
# 135  161.16  162.21  ...  149.51  150.70  151.46  156.65  154.04  154.75
# 136  158.76  149.06  ...  144.42  149.51  150.70  151.46  156.65  154.04
# 137  153.86  144.14  ...  151.68  144.42  149.51  150.70  151.46  156.65
#
#       PIBi9  PIBi10  PIBi11  PIBi12
# 133  154.49  150.92  151.44  148.92
# ...

# %%
# 3. Separação de Treino e Teste
# Geração de amostra em uma série temporal (falaremos mais sobre isto adiante)
# através de uma janela temporal
treino = df.iloc[0:124]
teste  = df.iloc[125:137]

# %%
# 4. Construção das variáveis para regressão linear

# TREINO
# Variável X - localizamos a variável BRP na 4a posição indicial 
# Exercício: experimentar com diferentes variáveis e diferentes combinações de variáveis, avaliando o resultado do modelo preditivo
X_treino = treino.loc[:,['PRP', 'BRT']]

# Variável Y - PIB
Y_treino = treino.iloc[:,[2]]

# %%
# 5. Construção regressão
mod = LinearRegression()
mod.fit(X_treino,Y_treino)
# Out:
# LinearRegression()

# %%
# 6. Previsão em teste
X_teste = teste.loc[:,['PRP', 'BRT']]
Y_teste = teste.iloc[:,[2]]

Y_prev = mod.predict(X_teste)

# %%
# 7. Análise do Erro de Previsão
erro_aprox = Y_prev - Y_teste
erro_aprox

# Erro Médio (* implementar uma fórmula de cálculo)
# Out:
#            PIB
# 125  -2.462469
# 126   1.464065
# 127   1.671090
# 128  -2.389105
# 129   1.476684
# 130   2.131593
# 131  10.359852
# 132  12.698862
# 133  -4.440392
# 134   3.638292
# 135   3.648903
# 136   1.830935
