# %% [markdown]
# <a href="https://colab.research.google.com/github/diogenesjusto/FIAP/blob/master/Gradua%C3%A7%C3%A3o/2020/20200811/Previsao_Babas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook com código básico de machine learning
# Previsão de vendas de babás eletrônicas
# Fontes de dados:
#
# Cedida por um site de web-commerce; vendas de babás eletrônicas no Brasil.

# %%
from sklearn.linear_model import LinearRegression
import numpy as np 
import pandas as pd
train = pandas.read_csv('https://raw.githubusercontent.com/diogenesjusto/FIAP/master/Gradua%C3%A7%C3%A3o/2020/20200804/train_BABA.csv')
test = pandas.read_csv('https://raw.githubusercontent.com/diogenesjusto/FIAP/master/Gradua%C3%A7%C3%A3o/2020/20200804/test_BABA.csv')
print(train)
# Out:
#      Unnamed: 0      date     mes  ...      desconto  outdesc  outmg
# 0             1  20140801  agosto  ...   9190.907534        0      0
# 1             2  20140802  agosto  ...   5713.043012        0      0
# 2             3  20140803  agosto  ...   8621.708915        0      0
# 3             4  20140804  agosto  ...  18312.965640        0      0
# 4             5  20140805  agosto  ...  19942.741300        0      0
# ..          ...       ...     ...  ...           ...      ...    ...
# 360         361  20150727   julho  ...   3487.843143        0      0
# 361         362  20150728   julho  ...   4965.290000        0      0
# 362         363  20150729   julho  ...   3477.950004        0      0
# 363         364  20150730   julho  ...   4328.840013        0      0
# 364         365  20150731   julho  ...   3378.833130        0      0
#
# [365 rows x 9 columns]

# %%
# Análise exploratória - comportamento vendas
train.iloc[:, 5].plot.line()

# %%
# Análise de correlação entre venda e desconto
train.plot.scatter(x='venda', y='desconto',)

# %%
mod1 = LinearRegression()  
X = train.iloc[:, [6]].values.reshape(-1, 1) 
Y = train.iloc[:, 5].values.reshape(-1, 1)  
mod1.fit(X, Y)  # linear regression
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
X_Prev = test.iloc[:, [5]].values.reshape(-1, 1)
prev = mod1.predict(X_Prev)  
print(prev)
# Out:
# [[ 56506.92941141]
#  [ 58617.10336985]
#  [ 59430.33399375]
#  [ 51220.97815506]
#  [ 69665.12990316]
#  [ 63856.63193176]
#  [ 59765.9818563 ]
#  [ 46151.16043641]
#  [ 45808.45439328]
#  [ 65116.46744065]
#  [ 57815.5861843 ]
#  [ 54903.64644413]
#  [228496.47464634]
#  [146795.85806705]
#  [ 40211.18448985]
#  [ 41639.69594263]
#  [ 71092.52937327]
#  [ 55269.7588863 ]
#  [ 74662.17054739]
#  [ 50293.42860142]
#  [ 70269.59859757]
#  [ 38451.98910604]
#  [ 52262.32689196]
#  [ 63197.10058208]
#  [ 40969.19819838]
#  [ 63438.86642711]
#  [ 73405.43838788]
#  [ 52117.98384244]
#  [ 36171.73858426]
#  [ 57305.77315812]
#  [ 48544.50334524]]

# %%
from google.colab import files

pd.DataFrame(prev).to_csv("filename.csv", header=False)

files.download('filename.csv')
