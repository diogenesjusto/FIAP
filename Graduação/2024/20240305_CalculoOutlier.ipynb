# %% [markdown]
# <a href="https://colab.research.google.com/github/diogenesjusto/FIAP/blob/master/Gradua%C3%A7%C3%A3o/2024/20240305_CalculoOutlier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

df = pd.read_csv("https://raw.githubusercontent.com/diogenesjusto/FIAP/master/Gradua%C3%A7%C3%A3o/dados/diamonds.csv")
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %% [markdown]
# Cálculo de Outlier - Método Escore Z
#
# Z = (xi - Média)/DesvPad

# %%
# Vamos utilizar a função zscore do pacote stats
# vamos procurar outliers na variável price
df[( np.abs(stats.zscore(df['price']))>3 )]
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 26394       26395   2.19  Very Good     I     SI2   60.3   60.0  15907  8.29
# 26395       26396   2.01    Premium     H     VS2   61.1   61.0  15908  8.14
# 26396       26397   2.14    Premium     I     SI1   61.3   61.0  15913  8.32
# 26397       26398   2.14    Premium     I     SI2   60.1   58.0  15915  8.41
# 26398       26399   2.01    Premium     H     SI2   62.3   58.0  15917  8.11
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 27745       27746   2.00  Very Good     H     SI1   62.8   57.0  18803  7.95
# 27746       27747   2.07      Ideal     G     SI2   62.5   55.0  18804  8.20
# 27747       27748   1.51      Ideal     G      IF   61.7   55.0  18806  7.37
# 27748       27749   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90
# 27749       27750   2.29    Premium     I     VS2   60.8   60.0  18823  8.50
#
#           y     z
# 26394  8.33  5.01
# ...

# %%
df[['price']].hist()
# Out:
# array([[<Axes: title={'center': 'price'}>]], dtype=object)
