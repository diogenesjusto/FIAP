# %% [markdown]
# <a href="https://colab.research.google.com/github/diogenesjusto/FIAP/blob/master/SHIFT/202505/t45_aula5_parte2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Configurar menu Ambiente de Execução , alterar o tipo do ambiente de Python3 para R

# Instalação pacote
install.packages('party')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘TH.data’, ‘libcoin’, ‘matrixStats’, ‘multcomp’, ‘mvtnorm’, ‘modeltools’, ‘strucchange’, ‘coin’, ‘zoo’, ‘sandwich’

# %%
# Similar ao comando import do python
library("party")
# Out:
# Loading required package: grid
#
# Loading required package: mvtnorm
#
# Loading required package: modeltools
#
# Loading required package: stats4
#
# Loading required package: strucchange
#
# Loading required package: zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
#
# Loading required package: sandwich

# %%
# Similar pd.read_csv
df = read.csv("https://raw.githubusercontent.com/diogenesjusto/FIAP/master/Gradua%C3%A7%C3%A3o/dados/dados_arvore_titanic.csv")

# %%
# ctree = comando da biblioteca party utilizado para construir uma árvore de (probabilidades) de decisão
# similar ao sklearn.tree DecisionTree
# as.factor => transforma em uma variável categórica
mod = ctree(Survived ~ as.factor(Pclass)+as.factor(Sex)+Age, data=df)

# Apresentação gráfica da árvore de decisão
plot(mod, type='simple')
# Out:
# plot without title
